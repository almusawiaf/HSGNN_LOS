# %%
import os

from weighted_sum_precision.GNN_functions_patients_only import *
from weighted_sum_precision.GNN_SAGE import SAGE_MLC
from weighted_sum_precision.GNN_GCN import GCN_MLC


if __name__ == "__main__":
    num_Sample     = int(os.getenv('num_Sample', 250))  # Default to 10000 if not set
    num_Labels     = int(os.getenv('NUM_DISEASES', 203))  # Default to 100 if not set
    num_top_Labels = int(os.getenv('NUM_TOP_DISEASES', 203))  # Selecting the top most frequent labels
    disease_name   = os.getenv('DISEASE_FILE', f'DMPLB2')  # Default to 'sample/10000' if not set
    num_Meta_Path  = int(os.getenv('num_Meta_Path', 10))  # Default to 10
    num_epochs     = int(os.getenv('num_epochs', 50))    
    # ============================================================================

    saving_path = f'../Data/{num_Labels}_Diagnoses/{disease_name}/{num_Sample}/HGNN_data'

    GNN_model = SAGE_MLC
    with_SNF = False
    super_class = '' # '_sc'
    
    exp_name = f'{num_epochs}_epochs_SNF{super_class}'

    losses, val_metrics = main(saving_path, 
                               GNN_Model=GNN_model, 
                               num_epochs = num_epochs,
                               with_SNF = with_SNF,
                               exp_name = exp_name,
                               super_class = super_class, 
                               num_Meta_Path = num_Meta_Path,
                               top_k = 5,
                               num_D = num_top_Labels)

    plot_combined_metrics_and_loss(losses, val_metrics)

    if with_SNF:
        save_results(losses, val_metrics, f'{saving_path}/performance_SAGE_{num_epochs}_eps_SNF')
    else:
        save_results(losses, val_metrics, f'{saving_path}/performance_SAGE_{num_epochs}_eps')
# Out:
# 	- Loading the data...
# ../Data/203_Diagnoses/DMPLB2/501/HGNN_data
# /home/almusawiaf/MyDocuments/PhD_Projects/HGNN_Project2/GNN_Models/weighted_sum_precision/GNN_functions_patients_only.py:245: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   temp_Y = torch.load(f'{file_path}/Y{super_class}.pt')
# /home/almusawiaf/MyDocuments/PhD_Projects/HGNN_Project2/GNN_Models/weighted_sum_precision/GNN_functions_patients_only.py:247: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   X = torch.load(f'{file_path}/X.pt')
# 	- Generating the Data structure ...
# 	- Generating the train, test, and validation sets...
# 	- Number of meta-paths used is :22
# 	- Preparing the model...
# 	- Epochs...
# Epoch: 1/50, Loss: 10.5561, Val Precision: 0.1401, ACC: 0.0000, top_k: 0.2300, top_k=1: 0.2093
# Epoch: 2/50, Loss: 9.3062, Val Precision: 0.1601, ACC: 0.0000, top_k: 0.2300, top_k=1: 0.2093
# Epoch: 3/50, Loss: 7.6111, Val Precision: 0.1438, ACC: 0.0000, top_k: 0.2267, top_k=1: 0.2093
# Epoch: 4/50, Loss: 6.0062, Val Precision: 0.1684, ACC: 0.0000, top_k: 0.2233, top_k=1: 0.2093
# Epoch: 5/50, Loss: 4.5341, Val Precision: 0.1481, ACC: 0.0000, top_k: 0.2300, top_k=1: 0.2093
# Epoch: 6/50, Loss: 2.9097, Val Precision: 0.1207, ACC: 0.0000, top_k: 0.2200, top_k=1: 0.2093
# Epoch: 7/50, Loss: 1.5867, Val Precision: 0.0551, ACC: 0.0000, top_k: 0.2167, top_k=1: 0.2093
# Epoch: 8/50, Loss: 1.4568, Val Precision: 0.0521, ACC: 0.0000, top_k: 0.1967, top_k=1: 0.2093
# Epoch: 9/50, Loss: 2.0138, Val Precision: 0.0541, ACC: 0.0000, top_k: 0.1900, top_k=1: 0.2093
# Epoch: 10/50, Loss: 2.4558, Val Precision: 0.0510, ACC: 0.0000, top_k: 0.1900, top_k=1: 0.2093
# Epoch: 11/50, Loss: 2.7494, Val Precision: 0.0512, ACC: 0.0000, top_k: 0.1800, top_k=1: 0.2093
# Epoch: 12/50, Loss: 2.8783, Val Precision: 0.0504, ACC: 0.0000, top_k: 0.1767, top_k=1: 0.2093
# Epoch: 13/50, Loss: 2.8354, Val Precision: 0.0437, ACC: 0.0133, top_k: 0.1767, top_k=1: 0.2093
# Epoch: 14/50, Loss: 2.7277, Val Precision: 0.0111, ACC: 0.0533, top_k: 0.1833, top_k=1: 0.2093
# Epoch: 15/50, Loss: 2.6628, Val Precision: 0.0235, ACC: 0.0400, top_k: 0.1900, top_k=1: 0.2093
# Epoch: 16/50, Loss: 2.5833, Val Precision: 0.0143, ACC: 0.0133, top_k: 0.1867, top_k=1: 0.2093
# Epoch: 17/50, Loss: 2.4570, Val Precision: 0.0366, ACC: 0.0133, top_k: 0.1933, top_k=1: 0.2093
# Epoch: 18/50, Loss: 2.3192, Val Precision: 0.0692, ACC: 0.0133, top_k: 0.1867, top_k=1: 0.2093
# Epoch: 19/50, Loss: 2.1513, Val Precision: 0.0595, ACC: 0.0133, top_k: 0.2000, top_k=1: 0.2093
# Epoch: 20/50, Loss: 1.9154, Val Precision: 0.1424, ACC: 0.0133, top_k: 0.2300, top_k=1: 0.2093
# Epoch: 21/50, Loss: 1.8189, Val Precision: 0.1218, ACC: 0.0133, top_k: 0.2233, top_k=1: 0.2093
# Epoch: 22/50, Loss: 1.8839, Val Precision: 0.0789, ACC: 0.0133, top_k: 0.2067, top_k=1: 0.2093
# Epoch: 23/50, Loss: 1.8676, Val Precision: 0.0786, ACC: 0.0133, top_k: 0.2067, top_k=1: 0.2093
# Epoch: 24/50, Loss: 1.7626, Val Precision: 0.0652, ACC: 0.0000, top_k: 0.2067, top_k=1: 0.2093
# Epoch: 25/50, Loss: 1.6329, Val Precision: 0.0690, ACC: 0.0000, top_k: 0.2167, top_k=1: 0.2093
# Epoch: 26/50, Loss: 1.4783, Val Precision: 0.1012, ACC: 0.0400, top_k: 0.2233, top_k=1: 0.2093
# Epoch: 27/50, Loss: 1.3054, Val Precision: 0.1608, ACC: 0.0133, top_k: 0.2367, top_k=1: 0.2093
# Epoch: 28/50, Loss: 1.2199, Val Precision: 0.1062, ACC: 0.0000, top_k: 0.2300, top_k=1: 0.2093
# Epoch: 29/50, Loss: 1.1415, Val Precision: 0.0956, ACC: 0.0000, top_k: 0.2000, top_k=1: 0.2093
# Epoch: 30/50, Loss: 1.0922, Val Precision: 0.1048, ACC: 0.0000, top_k: 0.1967, top_k=1: 0.2093
# Epoch: 31/50, Loss: 1.1613, Val Precision: 0.1247, ACC: 0.0000, top_k: 0.2033, top_k=1: 0.2093
# Epoch: 32/50, Loss: 1.1959, Val Precision: 0.1206, ACC: 0.0000, top_k: 0.2200, top_k=1: 0.2093
# Epoch: 33/50, Loss: 1.1959, Val Precision: 0.1251, ACC: 0.0000, top_k: 0.2133, top_k=1: 0.2093
# Epoch: 34/50, Loss: 1.1419, Val Precision: 0.1418, ACC: 0.0133, top_k: 0.1967, top_k=1: 0.2093
# Epoch: 35/50, Loss: 1.0441, Val Precision: 0.0871, ACC: 0.0533, top_k: 0.1933, top_k=1: 0.2093
# Epoch: 36/50, Loss: 0.9644, Val Precision: 0.0717, ACC: 0.0400, top_k: 0.1900, top_k=1: 0.2093
# Epoch: 37/50, Loss: 0.9260, Val Precision: 0.0525, ACC: 0.0267, top_k: 0.1900, top_k=1: 0.2093
# Epoch: 38/50, Loss: 0.8690, Val Precision: 0.0758, ACC: 0.0133, top_k: 0.1933, top_k=1: 0.2093
# Epoch: 39/50, Loss: 0.8039, Val Precision: 0.0826, ACC: 0.0133, top_k: 0.2167, top_k=1: 0.2093
# Epoch: 40/50, Loss: 0.7939, Val Precision: 0.1003, ACC: 0.0000, top_k: 0.2233, top_k=1: 0.2093
# Epoch: 41/50, Loss: 0.8037, Val Precision: 0.1931, ACC: 0.0000, top_k: 0.2333, top_k=1: 0.2093
# Epoch: 42/50, Loss: 0.7991, Val Precision: 0.1897, ACC: 0.0133, top_k: 0.2400, top_k=1: 0.2093
# Epoch: 43/50, Loss: 0.8161, Val Precision: 0.1788, ACC: 0.0133, top_k: 0.2433, top_k=1: 0.2093
# Epoch: 44/50, Loss: 0.8298, Val Precision: 0.2074, ACC: 0.0133, top_k: 0.2333, top_k=1: 0.2093
# Epoch: 45/50, Loss: 0.7814, Val Precision: 0.1789, ACC: 0.0133, top_k: 0.2300, top_k=1: 0.2093
# Epoch: 46/50, Loss: 0.6826, Val Precision: 0.0976, ACC: 0.0667, top_k: 0.1933, top_k=1: 0.2093
# Epoch: 47/50, Loss: 0.6333, Val Precision: 0.1344, ACC: 0.0400, top_k: 0.1933, top_k=1: 0.2093
# Epoch: 48/50, Loss: 0.6526, Val Precision: 0.0729, ACC: 0.0400, top_k: 0.1933, top_k=1: 0.2093
# Epoch: 49/50, Loss: 0.6694, Val Precision: 0.0617, ACC: 0.0400, top_k: 0.2000, top_k=1: 0.2093
# {
#     "accuracy": 0.07894736842105263,
#     "micro_precision": 0.13953488372093023,
#     "macro_precision": 0.05653235653235653,
#     "recall": 0.07685185185185187,
#     "f1_score": 0.060659223817118545,
#     "auc": 0.4649796608922623,
#     "top_k_1": 0.2144736796617508,
#     "top_k_pred": 0.21710526943206787
# }
# 	- Extracting and saving embeddings...
#               precision    recall  f1-score   support
#
#      Class 0       0.00      0.00      0.00        23
#      Class 1       0.28      0.19      0.22        27
#      Class 2       0.00      0.00      0.00        20
#      Class 3       0.00      0.00      0.00        19
#      Class 4       0.19      0.42      0.26        12
#      Class 5       0.10      0.17      0.12        12
#      Class 6       0.00      0.00      0.00        11
#      Class 7       0.00      0.00      0.00        14
#      Class 8       0.00      0.00      0.00        15
#      Class 9       0.00      0.00      0.00        10
#
#    micro avg       0.14      0.07      0.10       163
#    macro avg       0.06      0.08      0.06       163
# weighted avg       0.07      0.07      0.07       163
#  samples avg       0.10      0.05      0.06       163
